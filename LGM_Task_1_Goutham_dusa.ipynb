# %% [markdown]
# <a href="https://colab.research.google.com/github/gouthamdusa/LGM_Tasks/blob/main/LGM_Task_1_Goutham_dusa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1 : Iris Flower Classification
# # Name : Goutham Dusa
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Loading Data

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Finding Missing value

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # Visualize the data set

# %%
sns.boxplot(data=df,x='species',y='sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(data=df,x='species',y='sepal_width')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(data=df,x='species',y='petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=df,x='species',y='petal_width')
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.pairplot(df,hue='species')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-14-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
sns.histplot(data=df,x="sepal_length",kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df,x="sepal_width",kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df,x="petal_length",kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=df,x="petal_width",kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# # Data Seperation

# %%
x=df.iloc[:,0:4]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,4]
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 30            4.8          3.1           1.6          0.2
# 31            5.4          3.4           1.5          0.4
# 89            5.5          2.5           4.0          1.3
# 90            5.5          2.6           4.4          1.2
# 55            5.7          2.8           4.5          1.3
# ..            ...          ...           ...          ...
# 102           7.1          3.0           5.9          2.1
# 100           6.3          3.3           6.0          2.5
# 44            5.1          3.8           1.9          0.4
# 132           6.4          2.8           5.6          2.2
# 117           7.7          3.8           6.7          2.2
#
# [120 rows x 4 columns]

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
knn=KNeighborsClassifier(n_neighbors=7)
knn
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
y_pred
# Out:
# array(['setosa', 'virginica', 'versicolor', 'virginica', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor', 'setosa',
#        'virginica', 'versicolor', 'virginica', 'virginica', 'setosa',
#        'virginica', 'versicolor', 'versicolor', 'virginica', 'versicolor',
#        'setosa', 'virginica', 'setosa', 'versicolor', 'virginica',
#        'setosa', 'virginica', 'virginica', 'virginica', 'virginica'],
#       dtype=object)

# %% [markdown]
# ## Accuracy

# %%
a=accuracy_score(y_test,y_pred)
print(a)
# Out:
# 0.9666666666666667

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
c_m=confusion_matrix(y_test,y_pred)
print(c_m)
# Out:
# [[ 6  0  0]
#  [ 0 10  0]
#  [ 0  1 13]]

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         6
#   versicolor       0.91      1.00      0.95        10
#    virginica       1.00      0.93      0.96        14
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.98      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
#creating random forest classifier
rfc=RandomForestClassifier(n_estimators=10) #By deafault Tress=100
rfc
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
#training the classifier
rfc.fit(x_train,y_train)
#applying the trained classifier to the test
y_pred=rfc.predict(x_test)
y_pred
# Out:
# array(['setosa', 'virginica', 'versicolor', 'virginica', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor', 'setosa',
#        'virginica', 'versicolor', 'virginica', 'virginica', 'setosa',
#        'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'virginica', 'setosa', 'versicolor',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'versicolor'], dtype=object)

# %% [markdown]
# #Accuracy

# %%
from sklearn.metrics import accuracy_score
a=accuracy_score(y_test,y_pred)
a
from sklearn.metrics import accuracy_score
a=accuracy_score(y_test,y_pred)
a
# Out:
# 0.9

# %%
from sklearn.metrics import  confusion_matrix
c_m=confusion_matrix(y_test,y_pred)
print(c_m)
# Out:
# [[ 6  0  0]
#  [ 0 10  0]
#  [ 0  3 11]]

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %% [markdown]
# # Conclusion
# After conducting Iris Flower Classification using Random Forest Classifier and KNN Classifier, it was observed that the KNN Classifier achieved an accuracy of 96%, while the Random Forest Classifier achieved an accuracy of 90%. Consequently, it can be inferred that the KNN Classifier outperforms the Random Forest Classifier in the classification of Iris Flowers.
